# %% [markdown]
# ### Dataset Information
# This dataset contains information on default payments, demographic factors, credit data, history of payment, and bill statements of credit card clients in Taiwan from April 2005 to September 2005.

# %% [markdown]
# ### There are 25 variables
# * ID: ID of each client
# * LIMIT_BAL: Amount of given credit in NT dollars (includes individual and family/supplementary credit) X_1
# * SEX: Gender (1=male, 2=female) X_2
# * EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown) X_3
# * MARRIAGE: Marital status (1=married, 2=single, 3=others) X_4
# * AGE: Age in years X_5
# * PAY_0: Repayment status in September, 2005 (-1=pay duly, 1=payment delay for one month, 2=payment delay for two months, … 8=payment delay for eight months, 9=payment delay for nine months and above) X_6
# * PAY_2: Repayment status in August, 2005 (scale same as above) X_7
# * PAY_3: Repayment status in July, 2005 (scale same as above) X_8
# * PAY_4: Repayment status in June, 2005 (scale same as above) X_9
# * PAY_5: Repayment status in May, 2005 (scale same as above) X_10
# * PAY_6: Repayment status in April, 2005 (scale same as above) X_11
# * -
# * BILL_AMT1: Amount of bill statement in September, 2005 (NT dollar) X_12
# * BILL_AMT2: Amount of bill statement in August, 2005 (NT dollar) X_13
# * BILL_AMT3: Amount of bill statement in July, 2005 (NT dollar) X_14
# * BILL_AMT4: Amount of bill statement in June, 2005 (NT dollar) X_15
# * BILL_AMT5: Amount of bill statement in May, 2005 (NT dollar) X_16
# * BILL_AMT6: Amount of bill statement in April, 2005 (NT dollar) X_17
# * -
# * PAY_AMT1: Amount of previous payment in September, 2005 (NT dollar) X_18
# * PAY_AMT2: Amount of previous payment in August, 2005 (NT dollar) X_19
# * PAY_AMT3: Amount of previous payment in July, 2005 (NT dollar) X_20
# * PAY_AMT4: Amount of previous payment in June, 2005 (NT dollar) X_21
# * PAY_AMT5: Amount of previous payment in May, 2005 (NT dollar) X_22
# * PAY_AMT6: Amount of previous payment in April, 2005 (NT dollar) X_23
# * default.payment.next.month: Default payment (1=yes, 0=no) Y

# %% [markdown]
# ### Inspiration
# Some ideas for exploration:
# * How does the probability of default payment vary by categories of different demographic variables?
# * Which variables are the strongest predictors of default payment?

# %% [markdown]
# ### Acknowledgements
# Any publications based on this dataset should acknowledge the following:
#
# Lichman, M. (2013). UCI Machine Learning Repository [http://archive.ics.uci.edu/ml]. Irvine, CA: University of California, School of Information and Computer Science.
#
# The original dataset can be found here at the UCI Machine Learning Repository.

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.datasets as dsets
import torchvision.transforms as transforms
import torch.utils.data as Data
from torch.autograd import Variable
from torchsampler import ImbalancedDatasetSampler

from sklearn.preprocessing import OneHotEncoder


import time

device = 'cuda' if torch.cuda.is_available() else 'cpu'
# device = 'cpu'
print(device)
# Out:
# cuda

# %%
df_credit_card = pd.read_csv("UCI_Credit_Card.csv")
df_credit_card.rename(columns={'PAY_0': 'PAY_1'}, inplace=True)
df_credit_card.tail()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29995      0  ...    88004.0    31237.0    15980.0    8500.0   20000.0
# 29996     -1  ...     8979.0     5190.0        0.0    1837.0    3526.0
# 29997     -1  ...    20878.0    20582.0    19357.0       0.0       0.0
# 29998      0  ...    52774.0    11855.0    48944.0   85900.0    3409.0
# 29999      0  ...    36535.0    32428.0    15313.0    2078.0    1800.0
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# 29995    5003.0    3047.0    5000.0    1000.0                           0
# 29996    8998.0     129.0       0.0       0.0                           0
# 29997   22000.0    4200.0    2000.0    3100.0                           1
# 29998    1178.0    1926.0   52964.0    1804.0                           1
# 29999    1430.0    1000.0    1000.0    1000.0                           1
#
# [5 rows x 25 columns]

# %% [markdown]
# ### EDA

# %%
temp = df_credit_card["default.payment.next.month"].value_counts()
df = pd.DataFrame({'default.payment.next.month': temp.index,'values': temp.values})
plt.figure(figsize = (6,6))
plt.title('Default Credit Card Clients - target value - data imbalanced\n (Default = 0, Not Default = 1)')
# sns.set_color_codes("pastel")
sns.barplot(x = 'default.payment.next.month', y="values", data=df, palette="Reds")
sns.color_palette('hls',10)
locs, labels = plt.xticks()
plt.savefig("./results/target_heatmap")

# %%
# heatmap for all countries
correlation_all = round(df_credit_card.corr(),2)
#print(correlation)

sns.set(style="white")
mask = np.zeros_like(correlation_all, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11, 11))
#cmap = sns.diverging_palette(220, 10, as_cmap=True)

heatmap_all = sns.heatmap(
              correlation_all, 
              mask = mask, 
              cmap = 'Reds', 
              vmin = -1.0,
              vmax = 1.0,
              linewidths = 0.5, 
              cbar_kws = {"shrink": 0.5},
              square = True,
              annot = True,
              annot_kws={"size":8})

heatmap_all = heatmap_all.get_figure()
heatmap_all.savefig("./results/heatmap_all.png")

# %%
plt.figure(figsize = (14,6))
plt.title('Amount of credit limit - Density Plot')
sns.distplot(df_credit_card['LIMIT_BAL'],kde=True,bins=200, color="red")
plt.show()

# %%
class_0 = df_credit_card.loc[df_credit_card['default.payment.next.month'] == 0]["LIMIT_BAL"]
class_1 = df_credit_card.loc[df_credit_card['default.payment.next.month'] == 1]["LIMIT_BAL"]
plt.figure(figsize = (14,6))
plt.title('Limit Balance grouped by Default Status Next Month')
#sns.set_color_codes("pastel")
sns.distplot(class_1,kde=True,bins=200,color="red")
sns.distplot(class_0,kde=True,bins=200,color="navy")
plt.legend(['Default','No Default'])
plt.savefig("./results/limit_balance_group_by_default")

# %% [markdown]
# ### Features Processing

# %%
# create new features: D = BILL_AMT - PAY_AMT
for num in range(1,6):
    df_credit_card['D%d' % (num)] = (df_credit_card['BILL_AMT%d' % (num+1)] - df_credit_card['PAY_AMT%d' % (num)]) / df_credit_card['LIMIT_BAL']
    
for num in range(1,6):
    df_credit_card['D6'] = df_credit_card['D%d' % (num)]/6

# %%
df_credit_card.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month', 'D1', 'D2', 'D3', 'D4', 'D5', 'D6'],
#       dtype='object')

# %%
def rnn_train_test_split(df, ratio):
    """
    split the train test df based on the ratio, ex: 0.8
    """
    length = len(df)
    idx = int(length*ratio)
    df_train = df.iloc[:idx,:]
    df_test = df.iloc[idx:,:]
    
    print(df_train.shape)
    print(df_test.shape)
    
    return df_train, df_test

# %%
df_train, df_test = rnn_train_test_split(df_credit_card, 0.8)
# Out:
# (24000, 31)
# (6000, 31)

# %%
def organize_dynamic_feat(df):
    """
    orgainze dynamic features for each ID
    """
    
    dynamic_features = ['PAY_1','PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6',
                        'BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6',
                        'PAY_AMT1','PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
                        'D1','D2','D3','D4','D5','D6',
                        'default.payment.next.month']
    
    #static_features = ['LIMIT_BAL','SEX','EDUCATION','MARRIAGE','AGE']
    
    df = df[dynamic_features]
    
    df_dynamic_all = []
    df_dynamic_label = []
    
    for row in range(len(df)):
        """
        for each ID
        """
        dynamic_feat_1 = df.iloc[row,0:6]
        dynamic_feat_2 = df.iloc[row,6:12]
        dynamic_feat_3 = df.iloc[row,12:18]
        dynamic_feat_4 = df.iloc[row,18:24]
        dynamic_feat_label = df.iloc[row,len(dynamic_features)-1] 
        
        single_data = np.array([dynamic_feat_1, dynamic_feat_2, dynamic_feat_3, dynamic_feat_4]).reshape(-1,4)
        single_label = np.array(dynamic_feat_label).reshape(-1,1)

        df_single_data = pd.DataFrame(data=single_data, columns=['PAY','BILL_AMT','PAY_AMT','D'])
        df_single_data_label = pd.DataFrame(data=single_label, columns=['label'])
        
        df_dynamic_all.append(df_single_data)
        df_dynamic_label.append(df_single_data_label)
    
    return df_dynamic_all, df_dynamic_label

# %%
df_dynamic_train, df_dynamic_train_label = organize_dynamic_feat(df_train)
df_dynamic_test, df_dynamic_test_label = organize_dynamic_feat(df_test)

# %%
def get_rnn_train_test(df_dynamic_train, df_dynamic_train_label, time_step, save):
    """
    get the training dataset and testing dataset for rnn
    """
 
    x_rnn = []
    y_rnn = []

    col_len = 4 # number of dynamice features
    
    for num in range(len(df_dynamic_train)):
        """
        for each ID
        """
        for row in range(0, len(df_dynamic_train[num])-time_step):
            x_rnn.append(df_dynamic_train[num].iloc[row:(row+time_step),0:(col_len)].values.reshape(len(df_dynamic_train[num].iloc[:,0:(col_len)].columns)*time_step))
            y_rnn.append(df_dynamic_train_label[num].values)
    
    
    x_rnn = torch.from_numpy(np.array(x_rnn)).reshape(-1,col_len*time_step,1).type(torch.FloatTensor)
    y_rnn = torch.from_numpy(np.array(y_rnn)).view(-1,1).type(torch.FloatTensor)
    
    if save=='train':
        torch.save(x_rnn, './model/x_rnn_train.pth')
        torch.save(y_rnn, './model/y_rnn_train.pth')
    
    if save=='test':
        torch.save(x_rnn, './model/x_rnn_test.pth')
        torch.save(y_rnn, './model/y_rnn_test.pth')
  

    print(x_rnn.shape, y_rnn.shape)
    dataset = Data.TensorDataset(x_rnn, y_rnn)
    
    return dataset

# %%
training_dataset = get_rnn_train_test(df_dynamic_train, 
                                      df_dynamic_train_label,
                                      time_step = 4,
                                      save = 'train')

testing_dataset = get_rnn_train_test(df_dynamic_test, 
                                     df_dynamic_test_label,
                                     time_step = 4,
                                     save = 'test')
# Out:
# torch.Size([48000, 16, 1]) torch.Size([48000, 1])
# torch.Size([12000, 16, 1]) torch.Size([12000, 1])

# %%
training_loader = Data.DataLoader(
    dataset = training_dataset,
    shuffle = True,
    batch_size = 256,                    
    num_workers = 4,              
)

testing_loader = Data.DataLoader(
    dataset = testing_dataset,
    shuffle = True,
    batch_size = 256,      
    num_workers = 4,            
)

# %%
class history_package():
    def __init__(self, neural_net, train_loader, test_loader, EPOCH, LR, model_type):
        
        self.net = neural_net
        self.optimizer = torch.optim.Adam(neural_net.parameters(), lr = LR)
        
        pos_weight = torch.tensor([4]).to(device) # solve the imbalance data problem
        self.criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
        
        self.train_loader = train_loader
        self.test_loader = test_loader
        self.EPOCH_ = EPOCH
        self.LR_ = LR
        self.net = self.net.to(device)
        self.model_type = model_type
        
        self.training_acc = []
        self.testing_acc = []
        
        if device == 'cuda':
            torch.backends.cudnn.benchmark = True

    def start(self):

        train_loss_list = []
        test_loss_list = []
        
        for epoch in range(self.EPOCH_):
            
            if epoch % 10 == 0:
                print("============================")
                print('Epoch:', epoch)
                

            train_loss = self.train(epoch)
            test_loss = self.test(epoch)

            train_loss_list.append(train_loss)
            test_loss_list.append(test_loss)
        
        return train_loss_list, test_loss_list, self.training_acc, self.testing_acc

    def train(self, epoch):
        
        self.net.train()
        train_loss = 0
        correct = 0
        total = 0
        
        
        for step, (batch_X, batch_y) in enumerate(self.train_loader):
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            self.optimizer.zero_grad()
            outputs = self.net(batch_X)
            
            
            loss = self.criterion(outputs, batch_y)
            loss.backward()
            self.optimizer.step()
            train_loss += loss.item()      
            
            predicted = (outputs >= 0.5) 
            total += batch_y.size(0)
            correct += predicted.eq(batch_y).sum().item()
            
        self.training_acc.append(100.*(correct/total))

        if epoch % 10 == 0:
            print('【Training】Loss: %.3f | Acc: %.3f%% (%d/%d)' % (train_loss, 100.*(correct/total), correct, total))
        
        # save the model
        
        if self.model_type == "LSTM":
            torch.save(self.net.state_dict(), './model/LSTM_model.pth')
        
        if self.model_type == "LSTM_pos_weight":
            torch.save(self.net.state_dict(), './model/LSTM_model_pos_weight.pth')
            

        return train_loss
    
    def test(self, epoch):
        
        self.net.eval()
        test_loss = 0
        correct = 0
        total = 0
        
        with torch.no_grad(): 
            for step, (batch_X, batch_y) in enumerate(self.test_loader):
                batch_X, batch_y = batch_X.to(device), batch_y.to(device)
                outputs = self.net(batch_X)
                
                loss = self.criterion(outputs, batch_y)
                
                test_loss += loss.item()
                
                predicted = (outputs >= 0.5)
                total += batch_y.size(0)
                correct += predicted.eq(batch_y).sum().item()                
        
        self.testing_acc.append(100.*(correct/total))

        if epoch % 10 == 0:
            print('【Testing】Loss: %.3f | Acc: %.3f%% (%d/%d)' % ( test_loss, 100.*(correct/total), correct, total ))
            
        
        return test_loss

# %%
# Here we define our model as a class
class LSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super(LSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):        
        out, _ = self.lstm(x, None)
        out = self.fc(out[:, -1, :])
        prob = F.sigmoid(out)
        
        return prob

# %%
start_time = time.time()

rnn_module = history_package(LSTM(input_dim=1,
                                  hidden_dim=512,
                                  num_layers=3,
                                  output_dim=1), 
                             training_loader, 
                             testing_loader, 
                             EPOCH=1000, 
                             LR=0.0001,
                             model_type = "LSTM_pos")

history_train_loss, history_test_loss, history_train_acc, history_test_acc = rnn_module.start()

end_time = time.time()
print('Training Time Cost: ',time.strftime("%H hr %M min %S sec", time.gmtime(end_time - start_time)))
# Out:
# ============================
# Epoch: 0
# 【Training】Loss: 208.592 | Acc: 71.927% (34525/48000)
# 【Testing】Loss: 49.176 | Acc: 77.017% (9242/12000)
# ============================
# Epoch: 10
# 【Training】Loss: 198.136 | Acc: 77.398% (37151/48000)
# 【Testing】Loss: 48.441 | Acc: 79.517% (9542/12000)
# ============================
# Epoch: 20
# 【Training】Loss: 197.988 | Acc: 77.273% (37091/48000)
# 【Testing】Loss: 48.503 | Acc: 79.508% (9541/12000)
# ============================
# Epoch: 30
# 【Training】Loss: 197.520 | Acc: 77.712% (37302/48000)
# 【Testing】Loss: 48.449 | Acc: 79.475% (9537/12000)
# ============================
# Epoch: 40
# 【Training】Loss: 197.458 | Acc: 77.662% (37278/48000)
# 【Testing】Loss: 48.452 | Acc: 79.142% (9497/12000)
# ============================
# Epoch: 50
# 【Training】Loss: 196.974 | Acc: 77.879% (37382/48000)
# 【Testing】Loss: 48.460 | Acc: 79.250% (9510/12000)
# ============================
# Epoch: 60
# 【Training】Loss: 196.947 | Acc: 77.852% (37369/48000)
# 【Testing】Loss: 48.482 | Acc: 79.600% (9552/12000)
# ============================
# Epoch: 70
# 【Training】Loss: 196.661 | Acc: 78.131% (37503/48000)
# 【Testing】Loss: 48.541 | Acc: 79.608% (9553/12000)
# ============================
# Epoch: 80
# 【Training】Loss: 196.394 | Acc: 78.160% (37517/48000)
# 【Testing】Loss: 48.480 | Acc: 79.258% (9511/12000)
# ============================
# Epoch: 90
# 【Training】Loss: 196.002 | Acc: 78.481% (37671/48000)
# 【Testing】Loss: 48.475 | Acc: 79.317% (9518/12000)
# ============================
# Epoch: 100
# 【Training】Loss: 195.552 | Acc: 78.812% (37830/48000)
# 【Testing】Loss: 48.470 | Acc: 79.592% (9551/12000)
# ============================
# Epoch: 110
# 【Training】Loss: 195.303 | Acc: 78.888% (37866/48000)
# 【Testing】Loss: 48.533 | Acc: 79.550% (9546/12000)
# ============================
# Epoch: 120
# 【Training】Loss: 194.640 | Acc: 79.321% (38074/48000)
# 【Testing】Loss: 48.544 | Acc: 79.583% (9550/12000)
# ============================
# Epoch: 130
# 【Training】Loss: 194.176 | Acc: 79.588% (38202/48000)
# 【Testing】Loss: 48.466 | Acc: 79.583% (9550/12000)
# ============================
# Epoch: 140
# 【Training】Loss: 194.019 | Acc: 79.583% (38200/48000)
# 【Testing】Loss: 48.500 | Acc: 79.483% (9538/12000)
# ============================
# Epoch: 150
# 【Training】Loss: 193.341 | Acc: 79.958% (38380/48000)
# 【Testing】Loss: 48.591 | Acc: 79.275% (9513/12000)
# ============================
# Epoch: 160
# 【Training】Loss: 192.915 | Acc: 80.119% (38457/48000)
# 【Testing】Loss: 48.601 | Acc: 79.408% (9529/12000)
# ============================
# Epoch: 170
# 【Training】Loss: 192.637 | Acc: 80.369% (38577/48000)
# 【Testing】Loss: 48.635 | Acc: 79.350% (9522/12000)
# ============================
# Epoch: 180
# 【Training】Loss: 192.220 | Acc: 80.604% (38690/48000)
# 【Testing】Loss: 48.557 | Acc: 79.642% (9557/12000)
# ============================
# Epoch: 190
# 【Training】Loss: 191.939 | Acc: 80.710% (38741/48000)
# 【Testing】Loss: 48.629 | Acc: 78.942% (9473/12000)
# ============================
# Epoch: 200
# 【Training】Loss: 191.604 | Acc: 81.017% (38888/48000)
# 【Testing】Loss: 48.597 | Acc: 79.550% (9546/12000)
# ============================
# Epoch: 210
# 【Training】Loss: 191.516 | Acc: 80.958% (38860/48000)
# 【Testing】Loss: 48.646 | Acc: 78.917% (9470/12000)
# ============================
# Epoch: 220
# 【Training】Loss: 191.217 | Acc: 81.060% (38909/48000)
# 【Testing】Loss: 48.681 | Acc: 78.725% (9447/12000)
# ============================
# Epoch: 230
# 【Training】Loss: 190.943 | Acc: 81.398% (39071/48000)
# 【Testing】Loss: 48.680 | Acc: 79.167% (9500/12000)
# ============================
# Epoch: 240
# 【Training】Loss: 190.856 | Acc: 81.427% (39085/48000)
# 【Testing】Loss: 48.619 | Acc: 79.400% (9528/12000)
# ============================
# Epoch: 250
# 【Training】Loss: 190.468 | Acc: 81.598% (39167/48000)
# 【Testing】Loss: 48.642 | Acc: 79.342% (9521/12000)
# ============================
# Epoch: 260
# 【Training】Loss: 190.330 | Acc: 81.748% (39239/48000)
# 【Testing】Loss: 48.614 | Acc: 79.483% (9538/12000)
# ============================
# Epoch: 270
# 【Training】Loss: 190.223 | Acc: 81.771% (39250/48000)
# 【Testing】Loss: 48.642 | Acc: 79.142% (9497/12000)
# ============================
# Epoch: 280
# 【Training】Loss: 190.027 | Acc: 81.965% (39343/48000)
# 【Testing】Loss: 48.611 | Acc: 79.192% (9503/12000)
# ============================
# Epoch: 290
# 【Training】Loss: 189.942 | Acc: 81.963% (39342/48000)
# 【Testing】Loss: 48.641 | Acc: 79.167% (9500/12000)
# ============================
# Epoch: 300
# 【Training】Loss: 189.658 | Acc: 82.125% (39420/48000)
# 【Testing】Loss: 48.673 | Acc: 79.317% (9518/12000)
# ============================
# Epoch: 310
# 【Training】Loss: 189.801 | Acc: 82.258% (39484/48000)
# 【Testing】Loss: 48.661 | Acc: 79.108% (9493/12000)
# ============================
# Epoch: 320
# 【Training】Loss: 189.530 | Acc: 82.246% (39478/48000)
# 【Testing】Loss: 48.674 | Acc: 79.417% (9530/12000)
# ============================
# Epoch: 330
# 【Training】Loss: 189.462 | Acc: 82.183% (39448/48000)
# 【Testing】Loss: 48.658 | Acc: 79.300% (9516/12000)
# ============================
# Epoch: 340
# 【Training】Loss: 189.377 | Acc: 82.283% (39496/48000)
# 【Testing】Loss: 48.683 | Acc: 79.350% (9522/12000)
# ============================
# Epoch: 350
# 【Training】Loss: 189.008 | Acc: 82.644% (39669/48000)
# 【Testing】Loss: 48.698 | Acc: 79.225% (9507/12000)
# ============================
# Epoch: 360
# 【Training】Loss: 188.918 | Acc: 82.577% (39637/48000)
# 【Testing】Loss: 48.697 | Acc: 79.117% (9494/12000)
# ============================
# Epoch: 370
# 【Training】Loss: 188.804 | Acc: 82.746% (39718/48000)
# 【Testing】Loss: 48.739 | Acc: 79.275% (9513/12000)
# ============================
# Epoch: 380
# 【Training】Loss: 188.613 | Acc: 82.779% (39734/48000)
# 【Testing】Loss: 48.717 | Acc: 79.458% (9535/12000)
# ============================
# Epoch: 390
# 【Training】Loss: 188.613 | Acc: 82.796% (39742/48000)
# 【Testing】Loss: 48.681 | Acc: 79.567% (9548/12000)
# ============================
# Epoch: 400
# 【Training】Loss: 188.808 | Acc: 82.767% (39728/48000)
# 【Testing】Loss: 48.711 | Acc: 79.325% (9519/12000)
# ============================
# Epoch: 410
# 【Training】Loss: 188.549 | Acc: 82.894% (39789/48000)
# 【Testing】Loss: 48.625 | Acc: 79.442% (9533/12000)
# ============================
# Epoch: 420
# 【Training】Loss: 188.350 | Acc: 82.950% (39816/48000)
# 【Testing】Loss: 48.647 | Acc: 79.533% (9544/12000)
# ============================
# Epoch: 430
# 【Training】Loss: 188.312 | Acc: 83.033% (39856/48000)
# 【Testing】Loss: 48.747 | Acc: 79.475% (9537/12000)
# ============================
# Epoch: 440
# 【Training】Loss: 188.321 | Acc: 82.977% (39829/48000)
# 【Testing】Loss: 48.706 | Acc: 79.625% (9555/12000)
# ============================
# Epoch: 450
# 【Training】Loss: 188.026 | Acc: 83.162% (39918/48000)
# 【Testing】Loss: 48.708 | Acc: 79.325% (9519/12000)
# ============================
# Epoch: 460
# 【Training】Loss: 188.100 | Acc: 83.075% (39876/48000)
# 【Testing】Loss: 48.749 | Acc: 79.475% (9537/12000)
# ============================
# Epoch: 470
# 【Training】Loss: 187.622 | Acc: 83.365% (40015/48000)
# 【Testing】Loss: 48.651 | Acc: 79.692% (9563/12000)
# ============================
# Epoch: 480
# 【Training】Loss: 187.729 | Acc: 83.425% (40044/48000)
# 【Testing】Loss: 48.730 | Acc: 79.267% (9512/12000)
# ============================
# Epoch: 490
# 【Training】Loss: 187.715 | Acc: 83.419% (40041/48000)
# 【Testing】Loss: 48.675 | Acc: 79.575% (9549/12000)
# ============================
# Epoch: 500
# 【Training】Loss: 187.696 | Acc: 83.335% (40001/48000)
# 【Testing】Loss: 48.817 | Acc: 78.958% (9475/12000)
# ============================
# Epoch: 510
# 【Training】Loss: 187.459 | Acc: 83.496% (40078/48000)
# 【Testing】Loss: 48.763 | Acc: 79.342% (9521/12000)
# ============================
# Epoch: 520
# 【Training】Loss: 187.664 | Acc: 83.429% (40046/48000)
# 【Testing】Loss: 48.730 | Acc: 79.592% (9551/12000)
# ============================
# Epoch: 530
# 【Training】Loss: 187.525 | Acc: 83.506% (40083/48000)
# 【Testing】Loss: 48.841 | Acc: 79.567% (9548/12000)
# ============================
# Epoch: 540
# 【Training】Loss: 187.206 | Acc: 83.702% (40177/48000)
# 【Testing】Loss: 48.784 | Acc: 79.467% (9536/12000)
# ============================
# Epoch: 550
# 【Training】Loss: 187.161 | Acc: 83.775% (40212/48000)
# 【Testing】Loss: 48.814 | Acc: 79.350% (9522/12000)
# ============================
# Epoch: 560
# 【Training】Loss: 187.168 | Acc: 83.715% (40183/48000)
# 【Testing】Loss: 48.832 | Acc: 79.317% (9518/12000)
# ============================
# Epoch: 570
# 【Training】Loss: 186.905 | Acc: 84.042% (40340/48000)
# 【Testing】Loss: 48.804 | Acc: 79.625% (9555/12000)
# ============================
# Epoch: 580
# 【Training】Loss: 186.880 | Acc: 84.062% (40350/48000)
# 【Testing】Loss: 48.813 | Acc: 79.483% (9538/12000)
# ============================
# Epoch: 590
# 【Training】Loss: 186.856 | Acc: 83.969% (40305/48000)
# 【Testing】Loss: 48.838 | Acc: 79.483% (9538/12000)
# ============================
# Epoch: 600
# 【Training】Loss: 186.667 | Acc: 84.004% (40322/48000)
# 【Testing】Loss: 48.817 | Acc: 79.308% (9517/12000)
# ============================
# Epoch: 610
# 【Training】Loss: 186.874 | Acc: 83.898% (40271/48000)
# 【Testing】Loss: 48.827 | Acc: 79.375% (9525/12000)
# ============================
# Epoch: 620
# 【Training】Loss: 186.366 | Acc: 84.262% (40446/48000)
# 【Testing】Loss: 48.842 | Acc: 79.400% (9528/12000)
# ============================
# Epoch: 630
# 【Training】Loss: 186.533 | Acc: 84.281% (40455/48000)
# 【Testing】Loss: 48.837 | Acc: 79.300% (9516/12000)
# ============================
# Epoch: 640
# 【Training】Loss: 186.279 | Acc: 84.315% (40471/48000)
# 【Testing】Loss: 48.858 | Acc: 79.267% (9512/12000)
# ============================
# Epoch: 650
# 【Training】Loss: 186.354 | Acc: 84.223% (40427/48000)
# 【Testing】Loss: 48.838 | Acc: 79.542% (9545/12000)
# ============================
# Epoch: 660
# 【Training】Loss: 186.248 | Acc: 84.321% (40474/48000)
# 【Testing】Loss: 48.865 | Acc: 79.417% (9530/12000)
# ============================
# Epoch: 670
# 【Training】Loss: 186.475 | Acc: 84.021% (40330/48000)
# 【Testing】Loss: 48.949 | Acc: 79.283% (9514/12000)
# ============================
# Epoch: 680
# 【Training】Loss: 186.237 | Acc: 84.250% (40440/48000)
# 【Testing】Loss: 48.909 | Acc: 79.258% (9511/12000)
# ============================
# Epoch: 690
# 【Training】Loss: 185.978 | Acc: 84.452% (40537/48000)
# 【Testing】Loss: 48.943 | Acc: 79.333% (9520/12000)
# ============================
# Epoch: 700
# 【Training】Loss: 185.756 | Acc: 84.462% (40542/48000)
# 【Testing】Loss: 48.853 | Acc: 79.508% (9541/12000)
# ============================
# Epoch: 710
# 【Training】Loss: 185.888 | Acc: 84.385% (40505/48000)
# 【Testing】Loss: 48.933 | Acc: 79.292% (9515/12000)
# ============================
# Epoch: 720
# 【Training】Loss: 185.658 | Acc: 84.708% (40660/48000)
# 【Testing】Loss: 48.924 | Acc: 79.150% (9498/12000)
# ============================
# Epoch: 730
# 【Training】Loss: 185.521 | Acc: 84.652% (40633/48000)
# 【Testing】Loss: 48.881 | Acc: 79.350% (9522/12000)
# ============================
# Epoch: 740
# 【Training】Loss: 185.473 | Acc: 84.623% (40619/48000)
# 【Testing】Loss: 48.956 | Acc: 79.183% (9502/12000)
# ============================
# Epoch: 750
# 【Training】Loss: 185.459 | Acc: 84.923% (40763/48000)
# 【Testing】Loss: 48.925 | Acc: 79.142% (9497/12000)
# ============================
# Epoch: 760
# 【Training】Loss: 185.420 | Acc: 84.713% (40662/48000)
# 【Testing】Loss: 48.956 | Acc: 79.125% (9495/12000)
# ============================
# Epoch: 770
# 【Training】Loss: 185.306 | Acc: 84.798% (40703/48000)
# 【Testing】Loss: 48.939 | Acc: 79.250% (9510/12000)
# ============================
# Epoch: 780
# 【Training】Loss: 185.380 | Acc: 84.710% (40661/48000)
# 【Testing】Loss: 48.928 | Acc: 79.550% (9546/12000)
# ============================
# Epoch: 790
# 【Training】Loss: 185.192 | Acc: 84.815% (40711/48000)
# 【Testing】Loss: 48.927 | Acc: 79.275% (9513/12000)
# ============================
# Epoch: 800
# 【Training】Loss: 185.448 | Acc: 84.621% (40618/48000)
# 【Testing】Loss: 48.960 | Acc: 79.058% (9487/12000)
# ============================
# Epoch: 810
# 【Training】Loss: 185.173 | Acc: 84.838% (40722/48000)
# 【Testing】Loss: 48.895 | Acc: 79.208% (9505/12000)
# ============================
# Epoch: 820
# 【Training】Loss: 184.914 | Acc: 84.933% (40768/48000)
# 【Testing】Loss: 49.065 | Acc: 78.942% (9473/12000)
# ============================
# Epoch: 830
# 【Training】Loss: 184.793 | Acc: 85.098% (40847/48000)
# 【Testing】Loss: 49.017 | Acc: 78.842% (9461/12000)
# ============================
# Epoch: 840
# 【Training】Loss: 184.854 | Acc: 84.975% (40788/48000)
# 【Testing】Loss: 48.939 | Acc: 79.208% (9505/12000)
# ============================
# Epoch: 850
# 【Training】Loss: 184.640 | Acc: 85.112% (40854/48000)
# 【Testing】Loss: 49.001 | Acc: 79.158% (9499/12000)
# ============================
# Epoch: 860
# 【Training】Loss: 184.522 | Acc: 85.177% (40885/48000)
# 【Testing】Loss: 49.028 | Acc: 79.042% (9485/12000)
# ============================
# Epoch: 870
# 【Training】Loss: 184.538 | Acc: 85.117% (40856/48000)
# 【Testing】Loss: 49.030 | Acc: 79.117% (9494/12000)
# ============================
# Epoch: 880
# 【Training】Loss: 184.354 | Acc: 85.283% (40936/48000)
# 【Testing】Loss: 48.960 | Acc: 79.325% (9519/12000)
# ============================
# Epoch: 890
# 【Training】Loss: 184.313 | Acc: 85.269% (40929/48000)
# 【Testing】Loss: 49.097 | Acc: 78.633% (9436/12000)
# ============================
# Epoch: 900
# 【Training】Loss: 184.223 | Acc: 85.298% (40943/48000)
# 【Testing】Loss: 48.998 | Acc: 79.083% (9490/12000)
# ============================
# Epoch: 910
# 【Training】Loss: 184.043 | Acc: 85.417% (41000/48000)
# 【Testing】Loss: 49.063 | Acc: 78.975% (9477/12000)
# ============================
# Epoch: 920
# 【Training】Loss: 183.914 | Acc: 85.485% (41033/48000)
# 【Testing】Loss: 49.036 | Acc: 78.892% (9467/12000)
# ============================
# Epoch: 930
# 【Training】Loss: 184.077 | Acc: 85.392% (40988/48000)
# 【Testing】Loss: 48.985 | Acc: 78.767% (9452/12000)
# ============================
# Epoch: 940
# 【Training】Loss: 183.973 | Acc: 85.429% (41006/48000)
# 【Testing】Loss: 49.023 | Acc: 79.033% (9484/12000)
# ============================
# Epoch: 950
# 【Training】Loss: 183.732 | Acc: 85.540% (41059/48000)
# 【Testing】Loss: 49.015 | Acc: 79.075% (9489/12000)
# ============================
# Epoch: 960
# 【Training】Loss: 183.803 | Acc: 85.548% (41063/48000)
# 【Testing】Loss: 49.072 | Acc: 79.042% (9485/12000)
# ============================
# Epoch: 970
# 【Training】Loss: 183.550 | Acc: 85.708% (41140/48000)
# 【Testing】Loss: 48.988 | Acc: 79.200% (9504/12000)
# ============================
# Epoch: 980
# 【Training】Loss: 183.824 | Acc: 85.500% (41040/48000)
# 【Testing】Loss: 49.050 | Acc: 79.233% (9508/12000)
# ============================
# Epoch: 990
# 【Training】Loss: 183.689 | Acc: 85.662% (41118/48000)
# 【Testing】Loss: 49.025 | Acc: 79.242% (9509/12000)
# Training Time Cost:  01 hr 02 min 05 sec

# %%
np.save("history_train_loss", history_train_loss)
np.save("history_test_loss", history_test_loss)
np.save("history_train_acc", history_train_acc)
np.save("history_test_acc", history_test_acc)

# %%
plt.figure(figsize=(12,6))
plt.plot(history_train_acc, color='orange', lw=2)
plt.xlabel("Number of Epochs")
plt.ylabel("Training Acc")
plt.title("Training Acc")
plt.savefig("./results/lstm_training_acc_pos")

# %%
plt.figure(figsize=(12,6))
plt.plot(history_test_acc, color='orange', lw=2)
plt.xlabel("Number of Epochs")
plt.ylabel("Testing Acc")
plt.title("Testing Acc")
plt.savefig("./results/lstm_testing_acc_pos")

# %%
plt.figure(figsize=(12,6))
plt.plot(history_train_loss, color='orange', lw=2)
plt.xlabel("Number of Epochs")
plt.ylabel("BCE Loss")
plt.title("LSTM Learning Curve")
plt.savefig("./results/lstm_learning_curve_pos")

# %% [markdown]
# ### Results

# %%
from sklearn.metrics import confusion_matrix

model_trained = LSTM(1,512,2,1)
model_trained.load_state_dict(torch.load("./model/LSTM_model_pos_weight.pth"))
model_trained.eval()
# Out:
# LSTM(
#   (lstm): LSTM(1, 512, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
y_true = torch.load('./model/y_rnn_test.pth').detach().numpy()
x_test = torch.load('./model/x_rnn_test.pth')

# %%
y_pred = model_trained(x_test[0:5000]) >= 0.5

# %%
y_true = y_true[0:5000]

# %%
cf = confusion_matrix(y_true, y_pred.detach().numpy())

# %%
df_confusion = pd.DataFrame(data=cf, columns=['No Default','Default'])
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(df_confusion, cmap='Reds') # font size

# %%
df_confusion
# Out:
#    No Default  Default
# 0        2950     1078
# 1         532      440

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, 
                            target_names=['No Default', 'Default']))
# Out:
#               precision    recall  f1-score   support
#
#   No Default       0.85      0.73      0.79      4028
#      Default       0.29      0.45      0.35       972
#
#     accuracy                           0.68      5000
#    macro avg       0.57      0.59      0.57      5000
# weighted avg       0.74      0.68      0.70      5000

# %%
from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(y_true, y_pred)

# %%
metrics.auc(fpr, tpr)
# Out:
# 0.592524141707635
